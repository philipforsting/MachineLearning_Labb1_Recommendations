# %% [markdown]
# # Machine Learning Assignment #

# %% [markdown]
# ## Introduktion ##

# %% [markdown]
# The assignment aims to create a recommendation system for movies based on an input movie. The recommendations are based on data avaiolable in data set ml-latest.
#
# The rapport desribes the analys of available data, methods and limitations

# %% [markdown]
# ## Data-analys (EDA) ##

# %% [markdown]
# The model is based on the movies, ratings and tags available in the mentioned data set ml-latest. Al datasets contain differet data for movies but the datasets are possible to link together by their movie id
#
# Movies.csv contains movie id, title, and genres for individual movies. The title is in the data set is the title of the movie together with the year it was released. The genres for each movie are grouped toghether but separated by a vertical bar [|]. The number of rows is 86537 and the number of valid tags are 19.
#
# ratings.csv contains movie ratings from individual users: movie id, user id, rating (0-5) and timestamp.
#
#
# tags contain individual tag for movies from individual users.

# %% [markdown]
# ## Modell ##

# %% [markdown]
#     Uvärdera modellen. Du kan jämföra modeller, tex i en tabell, men i löptexten
#     så behöver du bara beskriva den modell som du faktiskt använde i slutändan.
#     Se till beskriva resultatet både i ord och i en figur eller python output.

# %% [markdown]
# ## Resultat ##

# %% [markdown]
#     Förklara kortakommanden och/eller begränsningar och resonera kring vad resultatet
#     innebär för problemställningen.
